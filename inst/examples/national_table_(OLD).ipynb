# %%
source("inst/scripts/download_national_data.R")
download_national_data()
# Out:
# Downloading...
# All data is approx 14GB...
#   |                                                                      |   0%File already exists: raw_data/national_rtt/time_series//RTT-Overview-Timeseries-Including-Estimates-for-Missing-Trusts-Jul25-XLS-114K-92707.xlsx
#   |===================================                                   |  50% (50.0%)
# File already exists: raw_data/national_rtt/time_series//RTT-Overview-Timeseries-Jun15-revised-XLS-107K-92612.xls
#   |======================================================================| 100% (100.0%)
#
# [1] "Downloading CSV files..."
#   |                                                                      |   0%Downloading https://www.england.nhs.uk/statistics/wp-content/uploads/sites/2/2025/09/Full-CSV-data-file-Jul25-ZIP-4M-92707.zip to raw_data/national_rtt/csv//Full-CSV-data-file-Jul25-ZIP-4M-92707.zip
#   |=                                                                     |   1% (0.8%)
# ...

# %%
source("inst/scripts/process_national_data.R")
all <- load_national_incomplete(reload = FALSE, start_date = as.Date("1900-01-01"), end_date = as.Date("2100-12-31"))

# %%
source("inst/scripts/national_incomplete_stats.R")
process_incomplete_stats()
# Out:
#         Region_Code Provider_Code Provider_Name
# 1       Y56         R1H           BARTS HEALTH NHS TRUST
# 2       Y56         R1H           BARTS HEALTH NHS TRUST
# 3       Y56         R1H           BARTS HEALTH NHS TRUST
# 4       Y56         R1H           BARTS HEALTH NHS TRUST
# 5       Y56         R1H           BARTS HEALTH NHS TRUST
# 6       Y56         R1H           BARTS HEALTH NHS TRUST
# 7       Y56         R1H           BARTS HEALTH NHS TRUST
# 8       Y56         R1H           BARTS HEALTH NHS TRUST
# 9       Y56         R1H           BARTS HEALTH NHS TRUST
# 10      Y56         R1H           BARTS HEALTH NHS TRUST
# 11      Y56         R1H           BARTS HEALTH NHS TRUST
# 12      Y56         R1H           BARTS HEALTH NHS TRUST
# 13      Y56         R1H           BARTS HEALTH NHS TRUST
# 14      Y56         R1H           BARTS HEALTH NHS TRUST
# 15      Y56         R1H           BARTS HEALTH NHS TRUST
# 16      Y56         R1H           BARTS HEALTH NHS TRUST
# ...

# %%
View(all_national_incomplete)
# Out:
#         Region_Code Provider_Code Provider_Name
# 1       Y56         R1H           BARTS HEALTH NHS TRUST
# 2       Y56         R1H           BARTS HEALTH NHS TRUST
# 3       Y56         R1H           BARTS HEALTH NHS TRUST
# 4       Y56         R1H           BARTS HEALTH NHS TRUST
# 5       Y56         R1H           BARTS HEALTH NHS TRUST
# 6       Y56         R1H           BARTS HEALTH NHS TRUST
# 7       Y56         R1H           BARTS HEALTH NHS TRUST
# 8       Y56         R1H           BARTS HEALTH NHS TRUST
# 9       Y56         R1H           BARTS HEALTH NHS TRUST
# 10      Y56         R1H           BARTS HEALTH NHS TRUST
# 11      Y56         R1H           BARTS HEALTH NHS TRUST
# 12      Y56         R1H           BARTS HEALTH NHS TRUST
# 13      Y56         R1H           BARTS HEALTH NHS TRUST
# 14      Y56         R1H           BARTS HEALTH NHS TRUST
# 15      Y56         R1H           BARTS HEALTH NHS TRUST
# 16      Y56         R1H           BARTS HEALTH NHS TRUST
# ...
